# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %%
import mitsuba as mi
import drjit as dr
from matplotlib import pyplot as plt
import numpy as np

print(mi.variants())
mi.set_variant("cuda_ad_spectral_polarized")
# Out:
# ['scalar_rgb', 'scalar_spectral', 'scalar_spectral_polarized', 'llvm_ad_rgb', 'llvm_ad_mono', 'llvm_ad_mono_polarized', 'llvm_ad_spectral', 'llvm_ad_spectral_polarized', 'cuda_ad_rgb', 'cuda_ad_mono', 'cuda_ad_mono_polarized', 'cuda_ad_spectral', 'cuda_ad_spectral_polarized']

# %%
scene = mi.load_file("marcus_env_map.xml")
image = mi.render(scene, spp=4096)

plt.axis("off")
plt.imshow(image ** (1.0 / 2.2))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010034274..3.098182].
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
spp = 4096
scene = mi.load_file("marcus_env_map.xml")

parallel = mi.render(scene, spp=spp)

# Rotate camera polarizer by 90 deg
params = mi.traverse(scene)
params["polarizer_cam.bsdf.theta.value"] = 90
params.update()

orthogonal = mi.render(scene, spp=spp)

# Clip images to be >= 0
parallel[parallel < 0] = 0
orthogonal[orthogonal < 0] = 0

unpol = 2 * np.fmin(parallel, orthogonal)
pol = parallel - unpol / 2

diff = np.abs(parallel - orthogonal)

fig, ax = plt.subplots(1, 5, figsize=(20, 5))

ax[0].axis("off")
ax[0].imshow(parallel ** (1.0 / 2.2))
ax[0].set_title("Parallel Polarization")

ax[1].axis("off")
ax[1].imshow(orthogonal ** (1.0 / 2.2))
ax[1].set_title("Orthogonal Polarization")

ax[2].axis("off")
ax[2].imshow(unpol ** (1.0 / 2.2))
ax[2].set_title("Unpolarized (global)")

ax[3].axis("off")
ax[3].imshow(pol ** (1.0 / 2.2))
ax[3].set_title("Polarized (direct)")

ax[4].axis("off")
ax[4].imshow(diff ** (1.0 / 2.2))
ax[4].set_title("Difference (Parallel - Orthogonal)")

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010034278..3.098181].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.3516722].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..3.0981748].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0024264534..3.0981748].

# %%
params = mi.traverse(scene)
print(params)
# Out:
# SceneParameters[
#   -------------------------------------------------------------------------------------------------
#   Name                                          Flags    Type              Parent
#   -------------------------------------------------------------------------------------------------
#   sensor.near_clip                                       float             PerspectiveCamera
#   sensor.far_clip                                        float             PerspectiveCamera
#   sensor.shutter_open                                    float             PerspectiveCamera
#   sensor.shutter_open_time                               float             PerspectiveCamera
#   sensor.film.size                                       ScalarVector2u    HDRFilm
#   sensor.film.crop_size                                  ScalarVector2u    HDRFilm
#   sensor.film.crop_offset                                ScalarPoint2u     HDRFilm
#   sensor.x_fov                                  ∂, D     Float             PerspectiveCamera
#   sensor.principal_point_offset_x               ∂, D     Float             PerspectiveCamera
#   sensor.principal_point_offset_y               ∂, D     Float             PerspectiveCamera
#   sensor.to_world                               ∂, D     Transform4f       PerspectiveCamera
#   BitmapTextureImpl.data                        ∂        TensorXf          BitmapTextureImpl
#   BitmapTextureImpl.to_uv                                ScalarTransform3f BitmapTextureImpl
#   BitmapTextureImpl_1.data                      ∂        TensorXf          BitmapTextureImpl
#   BitmapTextureImpl_1.to_uv                              ScalarTransform3f BitmapTextureImpl
#   BitmapTextureImpl_2.data                      ∂        TensorXf          BitmapTextureImpl
#   BitmapTextureImpl_2.to_uv                              ScalarTransform3f BitmapTextureImpl
#   face.bsdf.diffuse_reflectance.data            ∂        TensorXf          BitmapTextureImpl
#   face.bsdf.diffuse_reflectance.to_uv                    ScalarTransform3f BitmapTextureImpl
#   face.bsdf.eta                                 ∂, D     Float             PolarizedPlastic
#   face.bsdf.specular_reflectance.data           ∂        TensorXf          BitmapTextureImpl
#   face.bsdf.specular_reflectance.to_uv                   ScalarTransform3f BitmapTextureImpl
#   face.bsdf.alpha                               ∂, D     Float             PolarizedPlastic
#   face.silhouette_sampling_weight                        float             OBJMesh
#   face.faces                                             UInt              OBJMesh
#   face.vertex_positions                         ∂, D     Float             OBJMesh
#   face.vertex_normals                           ∂, D     Float             OBJMesh
#   face.vertex_texcoords                         ∂        Float             OBJMesh
#   light.bsdf.reflectance.value                  ∂        Float             UniformSpectrum
#   light.emitter.sampling_weight                          float             AreaLight
#   light.emitter.radiance.value                  ∂        Color3f           D65Spectrum
#   light.emitter.radiance.d65.range                       ScalarVector2f    RegularSpectrum
#   light.emitter.radiance.d65.values             ∂        Float             RegularSpectrum
#   light.silhouette_sampling_weight                       float             Sphere
#   light.to_world                                ∂, D     Transform4f       Sphere
#   polarizer_light.bsdf.theta.value              ∂, D     Float             UniformSpectrum
#   polarizer_light.bsdf.transmittance.value      ∂        Float             UniformSpectrum
#   polarizer_light.silhouette_sampling_weight             float             Sphere
#   polarizer_light.to_world                      ∂, D     Transform4f       Sphere
#   polarizer_cam.bsdf.theta.value                ∂, D     Float             UniformSpectrum
#   polarizer_cam.bsdf.transmittance.value        ∂        Float             UniformSpectrum
#   polarizer_cam.silhouette_sampling_weight               float             OBJMesh
#   polarizer_cam.faces                                    UInt              OBJMesh
#   polarizer_cam.vertex_positions                ∂, D     Float             OBJMesh
#   polarizer_cam.vertex_normals                  ∂, D     Float             OBJMesh
#   polarizer_cam.vertex_texcoords                ∂        Float             OBJMesh
# ]
